# %%
# !pip install dtale

# %%
# !pip install dtale --upgrade pip

# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
import dtale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-COMHIUK:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install pandas-profiling --upgrade pip

# %%
pip install --upgrade pandas pandas-profiling

# %%
df2=sns.load_dataset('tips')
df2.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from pandas_profiling import ProfileReport

# Assuming 'df2' is your DataFrame that you want to profile
profile = ProfileReport(df2, explorative=True)

# The correct function name is 'to_file', not 'profile_to_file'
profile.to_file('output_pandas-profile.html')
# Out:
# 2023-07-31 08:59:51,753 - INFO     - Pandas backend NOT loaded
# 2023-07-31 08:59:51,785 - INFO     - Numpy backend NOT loaded
# 2023-07-31 08:59:51,794 - INFO     - Pyspark backend NOT loaded
# 2023-07-31 08:59:51,797 - INFO     - Python backend loaded
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       3 # Assuming 'df2' is your DataFrame that you want to profile
#       4 profile = ProfileReport(df2, explorative=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
# ...

# %%
# !pip install sweetviz --upgrade pip

# %%
import sweetviz as sv

my_report = sv.analyze(df2)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30264\1662755444.py in ?()
#       1 import sweetviz as sv
#       2
# ----> 3 my_report = sv.analyze(df2)
#       4 my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\sv_public.py in ?(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# ...

# %%
import pandas as pd

# Assuming 'df' is a valid Pandas DataFrame
print(type(df))  # Make sure it's a DataFrame

# Now you can proceed with sweetviz
import sweetviz as sv
report = sv.analyze(df)
report.show_html('sweetviz.html')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30264\3957009274.py in ?()
#       4 print(type(df))  # Make sure it's a DataFrame
#       5
#       6 # Now you can proceed with sweetviz
#       7 import sweetviz as sv
# ----> 8 report = sv.analyze(df)
#       9 report.show_html('sweetviz.html')
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sweetviz\sv_public.py in ?(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
# ...
